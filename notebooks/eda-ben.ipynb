# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_json('data/data.json')

# %%
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
# 3          premium          1388966400        12347         6      IE
# 4          premium          1297900800         2417        11      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
#
#                                          description  \
# 0  <p><a href="http://s432.photobucket.com/albums...
# 1  <p>Join us for a quick, one-night, community-b...
# 2  <h3><span class="subcategory"><strong>Teacher ...
# 3  <p style="margin-bottom: 1.3em; padding-bottom...
# 4  <p>Writers and filmmakers need to understand t...
#
# ...

# %%
df['acct_type'] = df['acct_type'].str.contains('fraud').map({True: 1, False: 0})

# %%
df.head()
# Out:
#    acct_type  approx_payout_date  body_length  channels country currency  \
# 0      fraud          1266062400         3852         5      US      USD
# 1  not fraud          1296720000         3499         0      US      USD
# 2  not fraud          1296172800         2601         8      US      USD
# 3  not fraud          1388966400        12347         6      IE      EUR
# 4  not fraud          1297900800         2417        11      US      USD
#
#    delivery_method                                        description  \
# 0              0.0  <p><a href="http://s432.photobucket.com/albums...
# 1              1.0  <p>Join us for a quick, one-night, community-b...
# 2              1.0  <h3><span class="subcategory"><strong>Teacher ...
# 3              1.0  <p style="margin-bottom: 1.3em; padding-bottom...
# 4              0.0  <p>Writers and filmmakers need to understand t...
#
#                  email_domain  event_created  ...  \
# 0                   gmail.com     1262739706  ...
# ...

# %%
df = df.rename(columns={'acct_type': 'fraud?'})

# %%
df.head()
# Out:
#    fraud?  approx_payout_date  body_length  channels country currency  \
# 0       1          1266062400         3852         5      US      USD
# 1       0          1296720000         3499         0      US      USD
# 2       0          1296172800         2601         8      US      USD
# 3       0          1388966400        12347         6      IE      EUR
# 4       0          1297900800         2417        11      US      USD
#
#    delivery_method                                        description  \
# 0              0.0  <p><a href="http://s432.photobucket.com/albums...
# 1              1.0  <p>Join us for a quick, one-night, community-b...
# 2              1.0  <h3><span class="subcategory"><strong>Teacher ...
# 3              1.0  <p style="margin-bottom: 1.3em; padding-bottom...
# 4              0.0  <p>Writers and filmmakers need to understand t...
#
#                  email_domain  event_created  ...  \
# 0                   gmail.com     1262739706  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
# fraud?                14337 non-null int64
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
df['fraud?'].sum()
# Out:
# 1293

# %%
1293/14337
# Out:
# 0.09018623142916929

# %%
df['ticket_types'][0]
# Out:
# [{'event_id': 527017,
#   'cost': 25.0,
#   'availability': 1,
#   'quantity_total': 800,
#   'quantity_sold': 0},
#  {'event_id': 527017,
#   'cost': 50.0,
#   'availability': 1,
#   'quantity_total': 100,
#   'quantity_sold': 0},
#  {'event_id': 527017,
#   'cost': 550.0,
#   'availability': 1,
#   'quantity_total': 20,
#   'quantity_sold': 0}]

# %%
df[(df['delivery_method']==0) &(df['fraud?']==1)]
# Out:
#        fraud?  approx_payout_date  body_length  channels country currency  \
# 0           1          1266062400         3852         5      US      USD
# 26          1          1299607200          870        11      US      USD
# 51          1          1329465600          536         6      US      USD
# 54          1          1312761600         3081        11              GBP
# 70          1          1322895600            0        13      US      USD
# ...       ...                 ...          ...       ...     ...      ...
# 14316       1          1360310400         3276         4      GB      GBP
# 14318       1          1359784800          448         0      US      USD
# 14325       1          1360049400          996         0      US      USD
# 14332       1          1361689200          667         0      US      USD
# 14336       1          1363316400            0         0      GB      GBP
#
#        delivery_method                                        description  \
# ...

# %%
import seaborn as sns
sns.countplot(x='delivery_method', hue='fraud?', data=df).set_title('deliver_method vs Fraud')
fig.savefig('images/fb_published.png')
# Out:
# Text(0.5, 1.0, 'deliver_method vs Fraud')

# %%
ax = sns.countplot(x='fb_published', hue='fraud?', data=df).set_title('fb_published vs Fraud')
fig = ax.get_figure()
fig.savefig('images/fb_published.png')

# %%
pd.set_option('display.max_columns', 50)

# %%
df.head()
# Out:
#    fraud?  approx_payout_date  body_length  channels country currency  \
# 0       1          1266062400         3852         5      US      USD
# 1       0          1296720000         3499         0      US      USD
# 2       0          1296172800         2601         8      US      USD
# 3       0          1388966400        12347         6      IE      EUR
# 4       0          1297900800         2417        11      US      USD
#
#    delivery_method                                        description  \
# 0              0.0  <p><a href="http://s432.photobucket.com/albums...
# 1              1.0  <p>Join us for a quick, one-night, community-b...
# 2              1.0  <h3><span class="subcategory"><strong>Teacher ...
# 3              1.0  <p style="margin-bottom: 1.3em; padding-bottom...
# 4              0.0  <p>Writers and filmmakers need to understand t...
#
#                  email_domain  event_created   event_end  event_published  \
# ...

# %%
sale_duration	sale_duration2, user_type

# %%
df['sale_duration2'].nunique()
# Out:
# 399

# %%
df['sale_duration2'].min()
# Out:
# -1094

# %%
import seaborn as sns
plt.figure(figsize=(20,6))
sns.countplot(x='sale_duration2', hue='fraud?', data=df, order=df.sale_duration2.iloc[:40].index).set_title("sale_duration2 vs fraud")
fig.savefig('images/sale_duration2.png')

# %%
#recommend including sale_duration2

# %%
import seaborn as sns
sns.countplot(x='sale_duration', hue='fraud?', data=df)

# %%
df['user_type'].nunique()
# Out:
# 6

# %%
ax = sns.countplot(x='user_type', hue='fraud?', data=df).set_title('user_type vs Fraud')
fig = ax.get_figure()
fig.savefig('images/user_type.png')

# %%
df[(df['user_type']==0) &(df['fraud?']==1)]
# Out:
# Empty DataFrame
# Columns: [fraud?, approx_payout_date, body_length, channels, country, currency, delivery_method, description, email_domain, event_created, event_end, event_published, event_start, fb_published, gts, has_analytics, has_header, has_logo, listed, name, name_length, num_order, num_payouts, object_id, org_desc, org_facebook, org_name, org_twitter, payee_name, payout_type, previous_payouts, sale_duration, sale_duration2, show_map, ticket_types, user_age, user_created, user_type, venue_address, venue_country, venue_latitude, venue_longitude, venue_name, venue_state]
# Index: []

# %%
df['ticket_types'][0][0]
# Out:
# {'event_id': 527017,
#  'cost': 25.0,
#  'availability': 1,
#  'quantity_total': 800,
#  'quantity_sold': 0}
